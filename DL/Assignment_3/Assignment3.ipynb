# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Dataset

# %%
train_df = pd.read_csv('fashion-mnist_train.csv')
test_df = pd.read_csv('fashion-mnist_test.csv')

# %%
train_df.shape
# Out:
# (60000, 785)

# %%
test_df.shape
# Out:
# (10000, 785)

# %%
train_df.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       4.500000      0.000900      0.006150      0.035333      0.101933
# std        2.872305      0.094689      0.271011      1.222324      2.452871
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000      0.000000
# 50%        4.500000      0.000000      0.000000      0.000000      0.000000
# 75%        7.000000      0.000000      0.000000      0.000000      0.000000
# max        9.000000     16.000000     36.000000    226.000000    164.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.247967      0.411467      0.805767      2.198283      5.682000
# std        4.306912      5.836188      8.215169     14.093378     23.819481
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      227.000000    230.000000    224.000000    255.000000    254.000000
#
#        ...      pixel775      pixel776      pixel777      pixel778  \
# count  ...  60000.000000  60000.000000  60000.000000  60000.000000
# mean   ...     34.625400     23.300683     16.588267     17.869433
# std    ...     57.545242     48.854427     41.979611     43.966032
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...     58.000000      9.000000      0.000000      0.000000
# max    ...    255.000000    255.000000    255.000000    255.000000
#
#            pixel779      pixel780      pixel781      pixel782      pixel783  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean      22.814817     17.911483      8.520633      2.753300      0.855517
# std       51.830477     45.149388     29.614859     17.397652      9.356960
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#           pixel784
# count  60000.00000
# mean       0.07025
# std        2.12587
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max      170.00000
#
# [8 rows x 785 columns]

# %%
train_df.label.unique()
# Out:
# array([2, 9, 6, 0, 3, 4, 5, 8, 7, 1], dtype=int64)

# %% [markdown]
# #### Each row represents an grayscale image containing 784 pixels and each pixel having values in range from 0-255
# #### The column label is a discrete value in the range 0 to 9 each value representing a specific category

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Preprocess Data
# Convert each image of 784 into (28x28x1)(height x width x color_channels). Divide values by 255 to scale the values.

# %%
x_train = train_df.iloc[:,1:].to_numpy()
x_train = x_train.reshape([-1,28,28,1])
x_train = x_train / 255

# %%
y_train = train_df.iloc[:,0].to_numpy()

# %%
x_test = test_df.iloc[:,1:].to_numpy()
x_test = x_test.reshape([-1,28,28,1])
x_test = x_test / 255

# %%
y_test = test_df.iloc[:,0].to_numpy()

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ### Model Building

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout

# %%
model = Sequential()

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=10, activation='sigmoid'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\nvs01\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10816)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │       346,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 347,114 (1.32 MB)
#  Trainable params: 347,114 (1.32 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=50,batch_size=1200,validation_split=0.05)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 11s 209ms/step - accuracy: 0.5727 - loss: 1.2920 - val_accuracy: 0.8230 - val_loss: 0.5125
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - accuracy: 0.8333 - loss: 0.4761 - val_accuracy: 0.8530 - val_loss: 0.4288
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 0.8590 - loss: 0.4048 - val_accuracy: 0.8740 - val_loss: 0.3820
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.8736 - loss: 0.3606 - val_accuracy: 0.8747 - val_loss: 0.3562
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.8815 - loss: 0.3375 - val_accuracy: 0.8800 - val_loss: 0.3412
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.8817 - loss: 0.3292 - val_accuracy: 0.8863 - val_loss: 0.3271
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 0.8913 - loss: 0.3124 - val_accuracy: 0.8857 - val_loss: 0.3202
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.8934 - loss: 0.3027 - val_accuracy: 0.8933 - val_loss: 0.3089
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.8986 - loss: 0.2924 - val_accuracy: 0.8913 - val_loss: 0.3082
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 213ms/step - accuracy: 0.8966 - loss: 0.2889 - val_accuracy: 0.8983 - val_loss: 0.2981
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 215ms/step - accuracy: 0.9019 - loss: 0.2778 - val_accuracy: 0.8970 - val_loss: 0.2916
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 212ms/step - accuracy: 0.9038 - loss: 0.2734 - val_accuracy: 0.9003 - val_loss: 0.2920
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 212ms/step - accuracy: 0.9057 - loss: 0.2676 - val_accuracy: 0.8963 - val_loss: 0.2896
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9057 - loss: 0.2648 - val_accuracy: 0.8990 - val_loss: 0.2847
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.9088 - loss: 0.2577 - val_accuracy: 0.9023 - val_loss: 0.2794
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 208ms/step - accuracy: 0.9123 - loss: 0.2449 - val_accuracy: 0.8997 - val_loss: 0.2763
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.9127 - loss: 0.2479 - val_accuracy: 0.9033 - val_loss: 0.2720
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9131 - loss: 0.2452 - val_accuracy: 0.9047 - val_loss: 0.2766
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9117 - loss: 0.2469 - val_accuracy: 0.9043 - val_loss: 0.2688
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.9171 - loss: 0.2353 - val_accuracy: 0.9097 - val_loss: 0.2660
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 207ms/step - accuracy: 0.9156 - loss: 0.2370 - val_accuracy: 0.9120 - val_loss: 0.2610
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.9182 - loss: 0.2284 - val_accuracy: 0.9010 - val_loss: 0.2737
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.9194 - loss: 0.2301 - val_accuracy: 0.9063 - val_loss: 0.2658
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 207ms/step - accuracy: 0.9189 - loss: 0.2261 - val_accuracy: 0.9110 - val_loss: 0.2591
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 208ms/step - accuracy: 0.9207 - loss: 0.2198 - val_accuracy: 0.9097 - val_loss: 0.2565
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.9223 - loss: 0.2189 - val_accuracy: 0.9140 - val_loss: 0.2564
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.9218 - loss: 0.2161 - val_accuracy: 0.9097 - val_loss: 0.2576
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 207ms/step - accuracy: 0.9236 - loss: 0.2164 - val_accuracy: 0.9073 - val_loss: 0.2647
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 213ms/step - accuracy: 0.9226 - loss: 0.2131 - val_accuracy: 0.9130 - val_loss: 0.2552
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 11s 219ms/step - accuracy: 0.9248 - loss: 0.2073 - val_accuracy: 0.9187 - val_loss: 0.2497
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 216ms/step - accuracy: 0.9269 - loss: 0.2047 - val_accuracy: 0.9133 - val_loss: 0.2528
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 212ms/step - accuracy: 0.9264 - loss: 0.2039 - val_accuracy: 0.9123 - val_loss: 0.2544
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 211ms/step - accuracy: 0.9292 - loss: 0.2009 - val_accuracy: 0.9167 - val_loss: 0.2529
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.9294 - loss: 0.1989 - val_accuracy: 0.9103 - val_loss: 0.2560
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9310 - loss: 0.1981 - val_accuracy: 0.9177 - val_loss: 0.2464
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9302 - loss: 0.1943 - val_accuracy: 0.9163 - val_loss: 0.2528
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.9319 - loss: 0.1927 - val_accuracy: 0.9160 - val_loss: 0.2530
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9291 - loss: 0.1935 - val_accuracy: 0.9160 - val_loss: 0.2497
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9349 - loss: 0.1856 - val_accuracy: 0.9180 - val_loss: 0.2434
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.9333 - loss: 0.1849 - val_accuracy: 0.9127 - val_loss: 0.2530
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 208ms/step - accuracy: 0.9335 - loss: 0.1850 - val_accuracy: 0.9123 - val_loss: 0.2490
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.9341 - loss: 0.1826 - val_accuracy: 0.9187 - val_loss: 0.2450
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9371 - loss: 0.1774 - val_accuracy: 0.9150 - val_loss: 0.2437
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 208ms/step - accuracy: 0.9390 - loss: 0.1742 - val_accuracy: 0.9183 - val_loss: 0.2439
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.9372 - loss: 0.1753 - val_accuracy: 0.9163 - val_loss: 0.2428
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - accuracy: 0.9362 - loss: 0.1742 - val_accuracy: 0.9187 - val_loss: 0.2422
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.9389 - loss: 0.1721 - val_accuracy: 0.9183 - val_loss: 0.2403
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9387 - loss: 0.1707 - val_accuracy: 0.9160 - val_loss: 0.2493
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 209ms/step - accuracy: 0.9387 - loss: 0.1715 - val_accuracy: 0.9137 - val_loss: 0.2577
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 216ms/step - accuracy: 0.9391 - loss: 0.1721 - val_accuracy: 0.9163 - val_loss: 0.2503

# %% [markdown]
# ### Evaluation

# %%
evaluation = model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9143 - loss: 0.2400

# %%
print(f"Accuracy: {evaluation[1]}")
# Out:
# Accuracy: 0.9185000061988831

# %%
y_probas = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
y_pred = y_probas.argmax(axis=-1)

# %%
y_pred
# Out:
# array([0, 1, 2, ..., 8, 8, 1], dtype=int64)

# %%
plt.figure(figsize=(10,10),)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
#     plt.xlabel(f"True Class:{y_test[i]}")
    plt.title(f"Pred:{class_names[y_pred[i]]}")
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
num_classes = 10
class_names = ["class {}".format(i) for i in range(num_classes)]
cr = classification_report(y_test, y_pred, target_names=class_names)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.81      0.91      0.86      1000
#      class 1       0.98      0.99      0.99      1000
#      class 2       0.88      0.87      0.88      1000
#      class 3       0.94      0.93      0.93      1000
#      class 4       0.88      0.90      0.89      1000
#      class 5       0.99      0.97      0.98      1000
#      class 6       0.81      0.71      0.76      1000
#      class 7       0.94      0.98      0.96      1000
#      class 8       0.98      0.98      0.98      1000
#      class 9       0.98      0.95      0.97      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
