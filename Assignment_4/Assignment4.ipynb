# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Loading the dataset

# %%
train_df = pd.read_csv('Google_Stock_Price_Train.csv')
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
test_df = pd.read_csv('Google_Stock_Price_Test.csv')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Open    20 non-null     float64
#  2   High    20 non-null     float64
#  3   Low     20 non-null     float64
#  4   Close   20 non-null     float64
#  5   Volume  20 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 1.1+ KB

# %% [markdown]
# #### Choosing column 'open' for predicition

# %%
train = train_df.loc[:,["Open"]].values
train.shape
# Out:
# (1258, 1)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)

# %%
plt.plot(train_scaled)
plt.ylabel("Standardized Values")
plt.xlabel("Time->")
plt.show()

# %% [markdown]
# ### Create data structure to train model
# Taking reference of past 60 days to predict future stock price
# x_train will have data of 60 days prior to current date and y_train will have price on current date

# %%
x_train = []
y_train = []
time = 60
for i in range(60,train_scaled.shape[0]):
    x_train.append(train_scaled[i-60:i,0])
    y_train.append(train_scaled[i,0])
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape,y_train.shape
# Out:
# ((1198, 60), (1198,))

# %%
x_train = np.reshape(x_train,newshape=(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1198, 60, 1)

# %% [markdown]
# ### Build model

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN,Dropout

# %%
model = Sequential()

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# C:\Users\nvs01\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 60, 50)         │         2,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 60, 50)         │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 60, 50)         │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 60, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,801 (69.54 KB)
#  Trainable params: 17,801 (69.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=100,batch_size=30,validation_split=0.05)
# Out:
# Epoch 1/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.5716 - val_loss: 0.0485
# Epoch 2/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2383 - val_loss: 0.0044
# Epoch 3/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1596 - val_loss: 7.7750e-04
# Epoch 4/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1460 - val_loss: 0.0164
# Epoch 5/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1099 - val_loss: 8.1390e-04
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0812 - val_loss: 0.0251
# Epoch 7/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0833 - val_loss: 0.0012
# Epoch 8/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0585 - val_loss: 0.0035
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0551 - val_loss: 0.0120
# Epoch 10/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0483 - val_loss: 0.0178
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0440 - val_loss: 8.2877e-04
# Epoch 12/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0375 - val_loss: 0.0147
# Epoch 13/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0338 - val_loss: 0.0044
# Epoch 14/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0261 - val_loss: 0.0227
# Epoch 15/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0268 - val_loss: 0.0144
# Epoch 16/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0265 - val_loss: 0.0041
# Epoch 17/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0218 - val_loss: 0.0134
# Epoch 18/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0205 - val_loss: 0.0027
# Epoch 19/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0186 - val_loss: 0.0027
# Epoch 20/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0158 - val_loss: 0.0186
# Epoch 21/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0154 - val_loss: 7.1162e-04
# Epoch 22/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0150 - val_loss: 0.0070
# Epoch 23/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0155 - val_loss: 0.0053
# Epoch 24/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0132 - val_loss: 0.0109
# Epoch 25/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0118 - val_loss: 0.0045
# Epoch 26/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 27/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0098 - val_loss: 0.0042
# Epoch 28/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0088 - val_loss: 0.0045
# Epoch 29/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0088 - val_loss: 0.0030
# Epoch 30/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0090 - val_loss: 0.0040
# Epoch 31/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0092 - val_loss: 6.0750e-04
# Epoch 32/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0082 - val_loss: 0.0028
# Epoch 33/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0072 - val_loss: 0.0026
# Epoch 34/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0079 - val_loss: 0.0011
# Epoch 35/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0067 - val_loss: 6.7117e-04
# Epoch 36/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0076 - val_loss: 0.0012
# Epoch 37/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0061 - val_loss: 0.0105
# Epoch 38/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0066 - val_loss: 0.0023
# Epoch 39/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 40/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 41/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 42/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0055 - val_loss: 0.0023
# Epoch 43/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0047 - val_loss: 9.9518e-04
# Epoch 44/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0050 - val_loss: 0.0065
# Epoch 45/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0056 - val_loss: 7.7117e-04
# Epoch 46/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0048 - val_loss: 0.0033
# Epoch 47/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 48/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0048 - val_loss: 0.0033
# Epoch 49/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 50/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0041 - val_loss: 6.0201e-04
# Epoch 51/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0044 - val_loss: 0.0026
# Epoch 52/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0041 - val_loss: 6.5750e-04
# Epoch 53/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 54/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 55/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0040 - val_loss: 5.3007e-04
# Epoch 56/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 57/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0041 - val_loss: 9.4116e-04
# Epoch 58/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0041 - val_loss: 6.2996e-04
# Epoch 59/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 60/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 61/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0032 - val_loss: 9.1587e-04
# Epoch 62/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0037 - val_loss: 7.9905e-04
# Epoch 63/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0036 - val_loss: 5.2940e-04
# Epoch 64/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0032 - val_loss: 9.2631e-04
# Epoch 65/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - val_loss: 6.6196e-04
# Epoch 66/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 67/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0031 - val_loss: 6.9569e-04
# Epoch 68/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0033 - val_loss: 6.2982e-04
# Epoch 69/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0027 - val_loss: 7.1444e-04
# Epoch 70/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0028 - val_loss: 5.6922e-04
# Epoch 71/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0025 - val_loss: 9.2755e-04
# Epoch 72/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0028 - val_loss: 7.1595e-04
# Epoch 73/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 74/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0027 - val_loss: 6.6009e-04
# Epoch 75/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0024 - val_loss: 0.0010
# Epoch 76/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0028 - val_loss: 8.1723e-04
# Epoch 77/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0026 - val_loss: 5.5306e-04
# Epoch 78/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0026 - val_loss: 6.7887e-04
# Epoch 79/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0026 - val_loss: 7.7245e-04
# Epoch 80/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0025 - val_loss: 7.8853e-04
# Epoch 81/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 82/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0024 - val_loss: 7.8399e-04
# Epoch 83/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0025 - val_loss: 6.5317e-04
# Epoch 84/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0022 - val_loss: 8.5408e-04
# Epoch 85/100
#  1/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0015

# %% [markdown]
# ### Prepare test dataset

# %%
data = pd.concat((train_df['Open'],test_df['Open']),axis=0)

# %%
test_input = data.iloc[len(data) - len(test_df) - time : ].values
test_input.shape

# %%
test_input = test_input.reshape(-1,1)
test_input.shape

# %%
test_scaled = scaler.transform(test_input)

# %% [markdown]
# #### Create test data set

# %%
x_test = []
for i in range(time,test_scaled.shape[0]):
    x_test.append(test_scaled[i - time: i,0 ])
x_test = np.array(x_test)
x_test.shape

# %%
x_test = np.reshape(x_test,newshape=(x_test.shape[0],x_test.shape[1],1))
x_test.shape

# %%
y_test = test_df.loc[:,"Open"].values

# %% [markdown]
# ### Model Prediction

# %%
y_pred = model.predict(x_test)

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
output = model.evaluate(x=x_test,y=y_test)

# %%
plt.plot(y_test, color = 'red', label = 'Real price')
plt.plot(y_pred, color = 'blue', label = 'Predicted price')

plt.title('Google Stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
